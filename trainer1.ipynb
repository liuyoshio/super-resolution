# %%
from src.datasets import MyDataset
from utils.helper import visualize_dataset
from utils.config import *

# %%
dataset = MyDataset(WorldStrat_path)

# %%
len(dataset)
# Out:
# 1799

# %%
visualize_dataset(dataset[12])
